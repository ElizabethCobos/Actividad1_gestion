# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargamos el archivo diamonds.csv
diamantes = pd.read_csv('diamonds.csv')
diamantes
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2    NaN   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#Detectamos valore nulos
nulos=diamantes.isnull().sum()
nulos
# Out:
# carat      3
# cut        0
# color      0
# clarity    0
# depth      2
# table      3
# price      3
# x          1
# y          1
# z          4
# dtype: int64

# %%
#Remplazamos los valores faltantes por la media aritmetica
data=diamantes.copy
data=diamantes.fillna(round(diamantes.mean(),1))
data
# Out:
# /var/folders/zv/01rx8f0176x702fr56drfp1m0000gn/T/ipykernel_4313/3341299408.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data=diamantes.fillna(round(diamantes.mean(),1))
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# ...

# %%
#Detectamos valore nulos
nulos=data.isnull().sum()
nulos
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
#Variable CARAT

y=data["carat"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)

#Encontramos Ouliers
outliers_carat= data[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_carat
# Out:
# Limite superior permitido 2.2199529087395717
# Limite inferior permitido -0.6240897274270025
#        carat        cut color clarity  depth  table    price     x     y     z
# 13757   2.22       Fair     J      I1   66.7   56.0   5607.0  8.04  8.02  5.36
# 14138   2.27       Fair     J      I1   67.6   55.0   5733.0  8.05  8.00  5.43
# 15684   2.49       Fair     J      I1   66.3   58.0   6289.0  8.26  8.18  5.45
# 16283   3.00  Very Good     H      I1   63.1   55.0   6512.0  9.23  9.10  5.77
# 16439   2.22       Fair     H      I1   70.1   55.0   6564.0  7.77  7.74  5.44
# ...      ...        ...   ...     ...    ...    ...      ...   ...   ...   ...
# 27727   2.61      Ideal     I     SI2   62.1   56.0  18756.0  8.85  8.73  5.46
# 27731   2.55    Premium     I     VS1   61.8   62.0  18766.0  8.70  8.65  5.36
# 27739   2.80       Good     G     SI2   63.8   58.0  18788.0  8.90  8.85  0.00
# 27744   2.29    Premium     I     SI1   61.8   59.0  18797.0  8.52  8.45  5.24
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data["carat"]) 
plt.title("Outliers de carat")
plt.show() #dibujamos el diagrama

# %%
#Variable DEPTH

y5=data["depth"]
Limite_Superior5= y.mean() + 3*y.std()
Limite_Inferior5= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior5)
print("Limite inferior permitido", Limite_Inferior5)

#Encontramos Ouliers
outliers_depth= data[(y5>Limite_Superior5)|(y5<Limite_Inferior5)]
outliers_depth
# Out:
# Limite superior permitido 2.2199529087395717
# Limite inferior permitido -0.6240897274270025
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data["depth"]) 
plt.title("Outliers de depth")
plt.show() #dibujamos el diagrama

# %%
#Variable TABLE

y6=data["table"]
Limite_Superior6= y.mean() + 3*y.std()
Limite_Inferior6= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior6)
print("Limite inferior permitido", Limite_Inferior6)

#Encontramos Ouliers
outliers_table= data[(y6>Limite_Superior6)|(y6<Limite_Inferior6)]
outliers_table
# Out:
# Limite superior permitido 2.2199529087395717
# Limite inferior permitido -0.6240897274270025
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data["table"]) 
plt.title("Outliers de table")
plt.show() #dibujamos el diagrama

# %%
#Variable PRICE

y7=data["price"]
Limite_Superior7= y.mean() + 3*y.std()
Limite_Inferior7= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior7)
print("Limite inferior permitido", Limite_Inferior7)

#Encontramos Ouliers
outliers_price= data[(y7>Limite_Superior7)|(y7<Limite_Inferior7)]
outliers_price
# Out:
# Limite superior permitido 2.2199529087395717
# Limite inferior permitido -0.6240897274270025
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data["price"]) 
plt.title("Outliers de price")
plt.show() #dibujamos el diagrama

# %%
#Variable x

y8=data["x"]
Limite_Superior8= y.mean() + 3*y.std()
Limite_Inferior8= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior8)
print("Limite inferior permitido", Limite_Inferior8)

#Encontramos Ouliers
outliers_equis = data[(y8>Limite_Superior8)|(y8<Limite_Inferior8)]
outliers_equis
# Out:
# Limite superior permitido 2.2199529087395717
# Limite inferior permitido -0.6240897274270025
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data["x"]) 
plt.title("Outliers de x")
plt.show() #dibujamos el diagrama

# %%
#Variable y

y9=data["y"]
Limite_Superior9= y.mean() + 3*y.std()
Limite_Inferior9= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior9)
print("Limite inferior permitido", Limite_Inferior9)

#Encontramos Ouliers
outliers_y = data[(y9>Limite_Superior9)|(y9<Limite_Inferior9)]
outliers_y
# Out:
# Limite superior permitido 2.2199529087395717
# Limite inferior permitido -0.6240897274270025
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data["y"]) 
plt.title("Outliers de y")
plt.show() #dibujamos el diagrama

# %%
#Variable z

y10=data["z"]
Limite_Superior10= y.mean() + 3*y.std()
Limite_Inferior10= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior10)
print("Limite inferior permitido", Limite_Inferior10)

#Encontramos Ouliers
outliers_z = data[(y10>Limite_Superior10)|(y10<Limite_Inferior10)]
outliers_z
# Out:
# Limite superior permitido 2.2199529087395717
# Limite inferior permitido -0.6240897274270025
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.7   58.0  2757.0  6.15  6.12  3.74
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data["z"]) 
plt.title("Outliers de z")
plt.show() #dibujamos el diagrama

# %% [markdown]
# *****Sustitución de outliers*****

# %%
#Realizamos una copia del dataframe
data2=data.copy()

# %%
#sustitución 1: CARAT
#Desviación estándar
data3=data2[(y<=Limite_Superior)&(y>=Limite_Inferior)] 
data3["carat"]=data3["carat"].fillna(round(data2["carat"].mean(),2))
# Out:
# /var/folders/zv/01rx8f0176x702fr56drfp1m0000gn/T/ipykernel_4313/302362612.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3["carat"]=data3["carat"].fillna(round(data2["carat"].mean(),2))

# %%
#sustitución 2: DEPTH
#Desviación estándar
data3=data2[(y5<=Limite_Superior5)&(y5>=Limite_Inferior5)] 
data3["depth"]=data3["depth"].fillna(round(data2["depth"].mean(),2))

# %%
#sustitución 3: TABLE
#Desviación estándar
data3=data2[(y6<=Limite_Superior6)&(y6>=Limite_Inferior6)] 
data3["table"]=data3["table"].fillna(round(data2["table"].mean(),2))

# %%
#sustitución 4: PRICE
#Desviación estándar
data3=data2[(y7<=Limite_Superior7)&(y7>=Limite_Inferior7)] 
data3["price"]=data3["price"].fillna(round(data2["price"].mean(),2))

# %%
#sustitución 5: X
#Desviación estándar
data3=data2[(y8<=Limite_Superior8)&(y8>=Limite_Inferior8)] 
data3["x"]=data3["x"].fillna(round(data2["x"].mean(),2))
# Out:
# /var/folders/zv/01rx8f0176x702fr56drfp1m0000gn/T/ipykernel_4313/298825143.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3["x"]=data3["x"].fillna(round(data2["x"].mean(),2))

# %%
#sustitución 6: y
#Desviación estándar
data3=data2[(y9<=Limite_Superior9)&(y9>=Limite_Inferior9)] 
data3["y"]=data3["y"].fillna(round(data2["y"].mean(),2))
# Out:
# /var/folders/zv/01rx8f0176x702fr56drfp1m0000gn/T/ipykernel_4313/941838491.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3["y"]=data3["y"].fillna(round(data2["y"].mean(),2))

# %%
#sustitución 7: z
#Desviación estándar
data3=data2[(y10<=Limite_Superior10)&(y9>=Limite_Inferior10)] 
data3["z"]=data3["z"].fillna(round(data2["z"].mean(),2))
# Out:
# /var/folders/zv/01rx8f0176x702fr56drfp1m0000gn/T/ipykernel_4313/3295732065.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3["z"]=data3["z"].fillna(round(data2["z"].mean(),2))
